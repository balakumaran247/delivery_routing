# %% [markdown]
# # Delivery Routing

# %% [markdown]
# ## Optimised Routing for effective Delivery system

# %% [markdown]
# Feed the input data on to the respective csv files in the data directory. (uno, lat, lon)
#
# origins.csv holds the information about the origin location from which the delivery vehicle starts its journey.
#
# - The program takes only one origin location.
#
# destinations.csv holds the information about the destination locations to which the delivery vehicle has to travel.
#
# - uno column must hold unique ids for all the locations

# %%
# imports
from deliveryrouting import generate_input
from deliveryrouting import delivery_routing

# %% [markdown]
# ## Reset the inputs
#
# Reset the inputs only when any one of the below is true,
#
# - You are running this program for the first time.
# - You have made any changes to the input csv files.
#
# Resetting will execute necessary calculations for the entire inputs and previous databases will be replaced.

# %%
# Reset the inputs
generate_input.main()
# Out:
# Calculating extent
#
# checking...
#
#
# generating the graph...
#
# generating the graphml file...
#
# [checked] osm graph
#
# calculating: [##########] 100.00% completed
# loading graph...
#
#
# calculating nearby node...
#
# calculating: [##########] 100.00% completed
# calculating route distances...
#
# calculating: [##########] 100.00% completed
# [checked] route distances.

# %% [markdown]
# ## Best Route Calculation

# %% [markdown]
# enter the excluded locations' "uno" ids seperated by comma (,) in the input feild which appears when the delivery_routing program executes

# %%
#Calculate Best Route
best_route, interactive_map = delivery_routing.main()
# Out:
# Exclude Locations:d0002
# calculating best route: [##########] 99.90% completed
# loading graph...
#
#
# Generating Interactive Map...

# %%
best_route
# Out:
# 'o0001 -> d0003 -> d0010 -> d0001 -> d0004 -> d0006 -> d0008 -> d0007 -> d0005 -> d0009'

# %%
interactive_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
